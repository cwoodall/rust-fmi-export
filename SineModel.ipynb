# %% [markdown]
# How is it going?

# %%
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

init_notebook_mode(connected=True)         # initiate notebook for offline plot

import fmpy
from fmpy import *


filename = 'SineModel.out.fmu'

# start_values = {}
start_values = {
    # variable      start   unit      description
    'frequency':       (20, 'Hz'),   # Frequency in Hz
}

output = [
    'output',  # output
]

result = simulate_fmu(filename, start_values=start_values, output=output, stop_time=.1, step_size = .0001, output_interval = .0001)


plot_result(result)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# fmi2Instantiate: GUID = {21d9f232-b090-4c79-933f-33da939b5934}
# ...

# %%
plot_result(result)
# Out:
# <div>                            <div id="15ef75dd-793d-4084-92cd-879c05c57e61" class="plotly-graph-div" style="height:280px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15ef75dd-793d-4084-92cd-879c05c57e61")) {                    Plotly.newPlot(                        "15ef75dd-793d-4084-92cd-879c05c57e61",                        [{"line":{"color":"#636efa","width":1},"marker":{"color":"#636efa","size":5},"name":"output","x":[0.0,0.1,0.2,0.30000000000000004,0.4,0.5,0.6000000000000001,0.7,0.8,0.9000000000000001,1.0,1.1,1.2000000000000002,1.3000000000000003,1.4,1.5,1.6,1.7000000000000002,1.8000000000000003,1.9,2.0,2.1,2.2,2.3,2.4000000000000004,2.5,2.6000000000000005,2.7,2.8,2.9000000000000004,3.0,3.1000000000000005,3.2,3.3,3.4000000000000004,3.5,3.6000000000000005,3.7,3.8,3.9000000000000004
# ...

# %%
result
# Out:
# SimulationResult([(  0. , 0.00000000e+00), (  0.1, 6.28318531e-06),
#                   (  0.2, 1.25663706e-05), ..., ( 99.8, 6.27057784e-03),
#                   ( 99.9, 6.27686090e-03), (100. , 6.28314397e-03)],
#                  dtype=[('time', '<f8'), ('output', '<f8')])
