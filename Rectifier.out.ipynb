# %% [markdown]
# Model Sine Wave

# %%
import fmpy
from fmpy import *


filename = 'Rectifier.out.fmu'

start_values = {
    # variable      start   unit      description
    'frequency':     (1000, 'Hz'),   # SineWave1.frequency
}

output = [
    'internalTime',  # internal time
    'output',        # SineWave1.out
]

import numpy as np
inputs = np.genfromtxt('Rectifier.out.csv', delimiter=',', names=True)
result = simulate_fmu(filename, input=inputs, start_values=start_values, output=output, stop_time=0.1)

plot_result(result)
# Out:
# ModelInstance { instanceName: 0x1079dfce0, GUID: 0x107c39950, fmuType: 1, loggingOn: 0, synced: 0, jsynced: 0, state: Instantiated, functions: fmi2CallbackFunctions { logger: Some(0x102cabeac), allocateMemory: Some(0x100fb8040), freeMemory: Some(0x100fb8050), stepFinished: None, componentEnvironment: 0x0 }, tolerance: 0.0, startTime: 0.0, stopTime: 0.0, stopTimeDefined: 0, initializeMode: 0, output: 0.0, time_elapsed: 0.0, frequency: 100.0, gain: 1.0 }
# ModelInstance { instanceName: 0x1079dfce0, GUID: 0x107c39950, fmuType: 1, loggingOn: 0, synced: 0, jsynced: 0, state: Instantiated, functions: fmi2CallbackFunctions { logger: Some(0x102cabeac), allocateMemory: Some(0x100fb8040), freeMemory: Some(0x100fb8050), stepFinished: None, componentEnvironment: 0x0 }, tolerance: 0.0, startTime: 0.0, stopTime: 0.0, stopTimeDefined: 0, initializeMode: 0, output: 0.0, time_elapsed: 0.0, frequency: 100.0, gain: 1.0 }
# ...
